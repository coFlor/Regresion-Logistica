# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special
from scipy.optimize import curve_fit
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('México por IQR2.csv')
df =df.drop(labels=["Unnamed: 0"], axis=1)
df
# Out:
#                         id           source  \
# 0                    35797      city scrape
# 1                    44616  previous scrape
# 2                    67703      city scrape
# 3                    70644      city scrape
# 4                   107078      city scrape
# ...                    ...              ...
# 26577  1252141718111439700      city scrape
# 26578  1252159821531694005      city scrape
# 26579  1252185591721328995      city scrape
# 26580  1252218347521498445      city scrape
# 26581  1252229157495978163      city scrape
#
#                                                    name  \
# 0                                           Villa Dante
# 1                                          Condesa Haus
# 2                     2 bedroom apt. deco bldg, Condesa
# 3      Beautiful light Studio Coyoacan- full equipped !
# 4                                    NEW  DESIGNER LOFT
# ...                                                 ...
# ...

# %%
df.columns
# Out:
# Index(['id', 'source', 'name', 'description', 'neighborhood_overview',
#        'host_id', 'host_name', 'host_response_time', 'host_is_superhost',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'amenities',
#        'has_availability', 'first_review', 'last_review', 'instant_bookable',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'minimum_nights',
#        'maximum_nights', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'host_response_rate',
#        'host_acceptance_rate', 'price', 'minimum_nights_avg_ntm',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            26582 non-null  int64
#  1   source                                        26582 non-null  object
#  2   name                                          26582 non-null  object
#  3   description                                   26582 non-null  object
#  4   neighborhood_overview                         26582 non-null  object
#  5   host_id                                       26582 non-null  int64
#  6   host_name                                     26582 non-null  object
#  7   host_response_time                            26582 non-null  object
#  8   host_is_superhost                             26582 non-null  object
# ...

# %% [markdown]
# **instant_bookable vs availability_30, host_acceptance_rate, price & beds**

# %%
#Declaramos las variables dependientes e independientes para la regresión logística
Vars_Indep=df[['availability_30','host_acceptance_rate','price','beds']] #De tipo numérico
Var_Dep=df['instant_bookable']

# %%
#Redefinimos las variables
X= Vars_Indep
y= Var_Dep

# %%
#Dividimos el conjunto de datos en la parte de entrenamiento y prueba:
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)

# %%
#Se escalan todos los datos
escalar = StandardScaler()

# %%
#Para realizar el escalamiento de las variables "X" tanto de entrenamiento como de prueba, utilizaremos
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
#Definimos el algoritmo a utilizar
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()

# %%
#Entrenamos el modelo
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Realizamos una predicción
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['f', 'f', 'f', ..., 'f', 'f', 'f'], dtype=object)

# %%
#Verifico la matriz de Confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[4454  385]
#  [2669  467]]

# %%
#Calculo la precisión del modelo
from sklearn.metrics import precision_score

precision1 = precision_score(y_test, y_pred, average="binary", pos_label="t")
print("Precisión del modelo: ")
print(precision1)
# Out:
# Precisión del modelo:
# 0.5481220657276995

# %%
from sklearn.metrics import precision_score

precision2 = precision_score(y_test, y_pred, average="binary", pos_label="f")
print("Precisión del modelo: ")
print(precision2)
# Out:
# Precisión del modelo:
# 0.6252983293556086

# %%
#Calculo la exactitud del modelo
from sklearn.metrics import accuracy_score

exactitud1 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud1)
# Out:
# Exactitud del modelo:
# 0.6170532915360502

# %%
#Calculo la sensibilidad del modelo
from sklearn.metrics import recall_score

sensibilidad1 = recall_score(y_test, y_pred, average="binary", pos_label="t")
print("Sensibilidad del modelo: ")
print(sensibilidad1)
# Out:
# Sensibilidad del modelo:
# 0.14891581632653061

# %%
from sklearn.metrics import recall_score

sensibilidad2 = recall_score(y_test, y_pred, average="binary", pos_label="f")
print("Sensibilidad del modelo: ")
print(sensibilidad2)
# Out:
# Sensibilidad del modelo:
# 0.9204381070469105

# %% [markdown]
# **source vs availability_30, price, latitude & longitude**

# %%
Vars_Indep=df[['availability_30','price','latitude','longitude']] #De tipo numérico
Var_Dep=df['source']

# %%
X= Vars_Indep
y= Var_Dep
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)

# %%
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
#
# Out:
# array(['city scrape', 'city scrape', 'city scrape', ..., 'city scrape',
#        'city scrape', 'city scrape'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[6924  160]
#  [ 790  101]]

# %%
from sklearn.metrics import precision_score

precision3 = precision_score(y_test, y_pred, average="binary", pos_label="city scrape") 
print("Precisión del modelo: ")
print(precision3)
# Out:
# Precisión del modelo:
# 0.8975887995851698

# %%
from sklearn.metrics import precision_score

precision4 = precision_score(y_test, y_pred, average="binary", pos_label="previous scrape") 
print("Precisión del modelo: ")
print(precision4)
# Out:
# Precisión del modelo:
# 0.38697318007662834

# %%
from sklearn.metrics import accuracy_score

exactitud2 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud2)
# Out:
# Exactitud del modelo:
# 0.8808777429467085

# %%
from sklearn.metrics import recall_score

sensibilidad3 = recall_score(y_test, y_pred, average="binary", pos_label="city scrape")
print("Sensibilidad del modelo: ")
print(sensibilidad3)
# Out:
# Sensibilidad del modelo:
# 0.9774138904573687

# %%
from sklearn.metrics import recall_score

sensibilidad4 = recall_score(y_test, y_pred, average="binary", pos_label="previous scrape")
print("Sensibilidad del modelo: ")
print(sensibilidad4)
# Out:
# Sensibilidad del modelo:
# 0.11335578002244669

# %% [markdown]
# **host_is_superhost vs host_response_rate & review_scores_rating**

# %%
Vars_Indep=df[['host_response_rate','host_acceptance_rate','review_scores_rating']] #De tipo numérico
Var_Dep=df['host_is_superhost']
X= Vars_Indep
y= Var_Dep
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['f', 'f', 'f', ..., 'f', 'f', 'f'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[3921 1004]
#  [2468  582]]

# %%
from sklearn.metrics import precision_score

precision5 = precision_score(y_test, y_pred, average="binary", pos_label="t") 
print("Precisión del modelo: ")
print(precision5)
# Out:
# Precisión del modelo:
# 0.3669609079445145

# %%
precision6 = precision_score(y_test, y_pred, average="binary", pos_label="f") 
print("Precisión del modelo: ")
print(precision6)
# Out:
# Precisión del modelo:
# 0.6137110658945062

# %%
exactitud3 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud3)
# Out:
# Exactitud del modelo:
# 0.5646394984326019

# %%
sensibilidad5 = recall_score(y_test, y_pred, average="binary", pos_label="t")
print("Sensibilidad del modelo: ")
print(sensibilidad5)
# Out:
# Sensibilidad del modelo:
# 0.19081967213114753

# %%
sensibilidad6 = recall_score(y_test, y_pred, average="binary", pos_label="f")
print("Sensibilidad del modelo: ")
print(sensibilidad6)
# Out:
# Sensibilidad del modelo:
# 0.7961421319796954

# %% [markdown]
# **has_availability vs availability_30, price & availability_60**

# %%
Vars_Indep=df[['availability_30','price','availability_60']] #De tipo numérico
Var_Dep=df['has_availability']
X= Vars_Indep
y= Var_Dep
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['t', 't', 't', ..., 't', 't', 't'], dtype=object)

# %%
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[   0   13]
#  [   0 7962]]

# %%
precision7 = precision_score(y_test, y_pred, average="binary", pos_label="t") 
print("Precisión del modelo: ")
print(precision7)
# Out:
# Precisión del modelo:
# 0.9983699059561129

# %%
precision8 = precision_score(y_test, y_pred, average="binary", pos_label="f") 
print("Precisión del modelo: ")
print(precision8)
# Out:
# Precisión del modelo:
# 0.0
# c:\Users\lalob\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
exactitud4 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud4)
# Out:
# Exactitud del modelo:
# 0.9983699059561129

# %%
sensibilidad7 = recall_score(y_test, y_pred, average="binary", pos_label="t")
print("Sensibilidad del modelo: ")
print(sensibilidad7)
# Out:
# Sensibilidad del modelo:
# 1.0

# %%
sensibilidad8 = recall_score(y_test, y_pred, average="binary", pos_label="f")
print("Sensibilidad del modelo: ")
print(sensibilidad8)
# Out:
# Sensibilidad del modelo:
# 0.0

# %% [markdown]
# **neighbourhood_cleansed vs latitude & longitude**

# %%
unico = np.unique(df["neighbourhood_cleansed"])
unico
# Out:
# array(['Azcapotzalco', 'Benito Juárez', 'Coyoacán',
#        'Cuajimalpa de Morelos', 'Cuauhtémoc', 'Gustavo A. Madero',
#        'Iztacalco', 'Iztapalapa', 'La Magdalena Contreras',
#        'Miguel Hidalgo', 'Milpa Alta', 'Tlalpan', 'Tláhuac',
#        'Venustiano Carranza', 'Xochimilco', 'Álvaro Obregón'],
#       dtype=object)

# %%
barrio_mas_frecuente = df['neighbourhood_cleansed'].value_counts()
barrio_mas_frecuente
# Out:
# neighbourhood_cleansed
# Cuauhtémoc                12231
# Miguel Hidalgo             4533
# Benito Juárez              3152
# Coyoacán                   1719
# Álvaro Obregón             1075
# Tlalpan                     812
# Venustiano Carranza         734
# Gustavo A. Madero           506
# Cuajimalpa de Morelos       442
# Iztacalco                   399
# Azcapotzalco                349
# Iztapalapa                  266
# La Magdalena Contreras      143
# Xochimilco                  143
# Tláhuac                      50
# Milpa Alta                   28
# Name: count, dtype: int64

# %%
df['neighbourhood_cleansed']= df['neighbourhood_cleansed'].replace(['Azcapotzalco', 'Benito Juárez', 'Coyoacán',
       'Cuajimalpa de Morelos', 'Gustavo A. Madero',
       'Iztacalco', 'Iztapalapa', 'La Magdalena Contreras',
       'Miguel Hidalgo', 'Milpa Alta', 'Tlalpan', 'Tláhuac',
       'Venustiano Carranza', 'Xochimilco', 'Álvaro Obregón'], "No Cuauhtémoc")
df["neighbourhood_cleansed"]
# Out:
# 0        No Cuauhtémoc
# 1           Cuauhtémoc
# 2           Cuauhtémoc
# 3        No Cuauhtémoc
# 4        No Cuauhtémoc
#              ...
# 26577    No Cuauhtémoc
# 26578    No Cuauhtémoc
# 26579    No Cuauhtémoc
# 26580    No Cuauhtémoc
# 26581    No Cuauhtémoc
# Name: neighbourhood_cleansed, Length: 26582, dtype: object

# %%
Vars_Indep=df[['latitude', 'longitude']] #De tipo numérico
Var_Dep=df['neighbourhood_cleansed']
X= Vars_Indep
y= Var_Dep
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['Cuauhtémoc', 'Cuauhtémoc', 'No Cuauhtémoc', ..., 'Cuauhtémoc',
#        'No Cuauhtémoc', 'No Cuauhtémoc'], dtype=object)

# %%
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[2341 1333]
#  [1604 2697]]

# %%
precision9 = precision_score(y_test, y_pred, average="binary", pos_label="Cuauhtémoc") 
print("Precisión del modelo: ")
print(precision9)
# Out:
# Precisión del modelo:
# 0.5934093789607098

# %%
precision10 = precision_score(y_test, y_pred, average="binary", pos_label="No Cuauhtémoc") 
print("Precisión del modelo: ")
print(precision10)
# Out:
# Precisión del modelo:
# 0.6692307692307692

# %%
exactitud5 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud5)
# Out:
# Exactitud del modelo:
# 0.6317241379310344

# %%
sensibilidad9 = recall_score(y_test, y_pred, average="binary", pos_label="Cuauhtémoc")
print("Sensibilidad del modelo: ")
print(sensibilidad9)
# Out:
# Sensibilidad del modelo:
# 0.6371801850843767

# %%
sensibilidad10 = recall_score(y_test, y_pred, average="binary", pos_label="No Cuauhtémoc")
print("Sensibilidad del modelo: ")
print(sensibilidad10)
# Out:
# Sensibilidad del modelo:
# 0.6270634736107882

# %% [markdown]
# **room_type vs accommodates, bathrooms, bedrooms & beds**

# %%
unico = np.unique(df["room_type"])
unico
# Out:
# array(['Entire home/apt', 'Hotel room', 'Private room', 'Shared room'],
#       dtype=object)

# %%
df['room_type']= df['room_type'].replace(['Hotel room','Private room', 'Shared room'], "No Entire home")
df["room_type"]
# Out:
# 0        Entire home/apt
# 1        Entire home/apt
# 2        Entire home/apt
# 3        Entire home/apt
# 4        Entire home/apt
#               ...
# 26577     No Entire home
# 26578     No Entire home
# 26579     No Entire home
# 26580     No Entire home
# 26581    Entire home/apt
# Name: room_type, Length: 26582, dtype: object

# %%
Vars_Indep=df[['accommodates','bathrooms','bedrooms','beds']] #De tipo numérico
Var_Dep=df['room_type']
X= Vars_Indep
y= Var_Dep
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['No Entire home', 'No Entire home', 'No Entire home', ...,
#        'No Entire home', 'No Entire home', 'Entire home/apt'],
#       dtype=object)

# %%
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[3605 1665]
#  [ 429 2276]]

# %%
precision11 = precision_score(y_test, y_pred, average="binary", pos_label="Entire home/apt") 
print("Precisión del modelo: ")
print(precision11)
# Out:
# Precisión del modelo:
# 0.8936539414972732

# %%
precision12 = precision_score(y_test, y_pred, average="binary", pos_label="No Entire home") 
print("Precisión del modelo: ")
print(precision12)
# Out:
# Precisión del modelo:
# 0.577518396346105

# %%
exactitud6 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud6)
# Out:
# Exactitud del modelo:
# 0.7374294670846395

# %%
sensibilidad11 = recall_score(y_test, y_pred, average="binary", pos_label="Entire home/apt")
print("Sensibilidad del modelo: ")
print(sensibilidad11)
# Out:
# Sensibilidad del modelo:
# 0.6840607210626186

# %%
sensibilidad12 = recall_score(y_test, y_pred, average="binary", pos_label="No Entire home")
print("Sensibilidad del modelo: ")
print(sensibilidad12)
# Out:
# Sensibilidad del modelo:
# 0.8414048059149722

# %% [markdown]
# **accommodates vs price, bathrooms, bedrooms & beds**

# %%
df['accommodates']
# Out:
# 0        2.0
# 1        3.0
# 2        4.0
# 3        2.0
# 4        2.0
#         ...
# 26577    4.0
# 26578    2.0
# 26579    2.0
# 26580    2.0
# 26581    2.0
# Name: accommodates, Length: 26582, dtype: float64

# %%
Min = df['accommodates'].min()
Max = df['accommodates'].max()

intervalos = [Min - 1, 3, Max]  # Min - 1 para asegurar incluir valores mínimos
categorias = ["3 o menos", "Más de 3"]

df['accommodates'] = pd.cut(df['accommodates'], bins=intervalos, labels=categorias, right=True)
df['accommodates']
# Out:
# 0        3 o menos
# 1        3 o menos
# 2         Más de 3
# 3        3 o menos
# 4        3 o menos
#            ...
# 26577     Más de 3
# 26578    3 o menos
# 26579    3 o menos
# 26580    3 o menos
# 26581    3 o menos
# Name: accommodates, Length: 26582, dtype: category
# Categories (2, object): ['3 o menos' < 'Más de 3']

# %%
df['accommodates'].isnull().sum()
# Out:
# 0

# %%
Vars_Indep=df[['price','bathrooms','bedrooms','beds']] #De tipo numérico
Var_Dep=df['accommodates']
X= Vars_Indep
y= Var_Dep
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['3 o menos', '3 o menos', '3 o menos', ..., '3 o menos',
#        '3 o menos', 'Más de 3'], dtype=object)

# %%
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[4721  496]
#  [ 570 2188]]

# %%
precision13 = precision_score(y_test, y_pred, average="binary", pos_label="Más de 3") 
print("Precisión del modelo: ")
print(precision13)
# Out:
# Precisión del modelo:
# 0.8152011922503726

# %%
precision14 = precision_score(y_test, y_pred, average="binary", pos_label="3 o menos") 
print("Precisión del modelo: ")
print(precision14)
# Out:
# Precisión del modelo:
# 0.8922698922698923

# %%
exactitud7 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud7)
# Out:
# Exactitud del modelo:
# 0.8663322884012539

# %%
sensibilidad13 = recall_score(y_test, y_pred, average="binary", pos_label="Más de 3")
print("Sensibilidad del modelo: ")
print(sensibilidad13)
# Out:
# Sensibilidad del modelo:
# 0.7933284989122552

# %%
sensibilidad14 = recall_score(y_test, y_pred, average="binary", pos_label="3 o menos")
print("Sensibilidad del modelo: ")
print(sensibilidad14)
# Out:
# Sensibilidad del modelo:
# 0.9049262027985432

# %% [markdown]
# **reviews_per_month vs number_of_reviews, number_of_reviews_ltm & number_of_reviews_l30d**

# %%
df['reviews_per_month']
# Out:
# 0        0.00
# 1        0.41
# 2        0.31
# 3        0.83
# 4        0.11
#          ...
# 26577    0.00
# 26578    0.00
# 26579    0.00
# 26580    0.00
# 26581    0.00
# Name: reviews_per_month, Length: 26582, dtype: float64

# %%
Min = df['reviews_per_month'].min()
Max = df['reviews_per_month'].max()

intervalos = [Min - 1, 1, Max]  # Min - 1 para asegurar incluir valores mínimos
categorias = ["1 o menos", "Más de 1"]

df['reviews_per_month'] = pd.cut(df['reviews_per_month'], bins=intervalos, labels=categorias, right=True)
df['reviews_per_month']
# Out:
# 0        1 o menos
# 1        1 o menos
# 2        1 o menos
# 3        1 o menos
# 4        1 o menos
#            ...
# 26577    1 o menos
# 26578    1 o menos
# 26579    1 o menos
# 26580    1 o menos
# 26581    1 o menos
# Name: reviews_per_month, Length: 26582, dtype: category
# Categories (2, object): ['1 o menos' < 'Más de 1']

# %%
Vars_Indep=df[['number_of_reviews','number_of_reviews_ltm','number_of_reviews_l30d']]
Var_Dep=df['reviews_per_month']
X= Vars_Indep
y= Var_Dep
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['Más de 1', 'Más de 1', '1 o menos', ..., 'Más de 1', 'Más de 1',
#        '1 o menos'], dtype=object)

# %%
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[3916  371]
#  [ 545 3143]]

# %%
precision15 = precision_score(y_test, y_pred, average="binary", pos_label="Más de 1") 
print("Precisión del modelo: ")
print(precision15)
# Out:
# Precisión del modelo:
# 0.8944223107569721

# %%
precision16 = precision_score(y_test, y_pred, average="binary", pos_label="1 o menos") 
print("Precisión del modelo: ")
print(precision16)
# Out:
# Precisión del modelo:
# 0.8778300829410446

# %%
exactitud8 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud8)
# Out:
# Exactitud del modelo:
# 0.885141065830721

# %%
sensibilidad15 = recall_score(y_test, y_pred, average="binary", pos_label="Más de 1")
print("Sensibilidad del modelo: ")
print(sensibilidad15)
# Out:
# Sensibilidad del modelo:
# 0.8522234273318872

# %%
sensibilidad16 = recall_score(y_test, y_pred, average="binary", pos_label="1 o menos")
print("Sensibilidad del modelo: ")
print(sensibilidad16)
# Out:
# Sensibilidad del modelo:
# 0.91345929554467

# %% [markdown]
# **review_scores_rating vs review_scores_cleanliness, review_scores_accuracy, review_scores_checkin, review_scores_communication, review_scores_location & review_scores_value**

# %%
df['review_scores_rating']
# Out:
# 0        4.80
# 1        4.58
# 2        4.90
# 3        4.91
# 4        4.91
#          ...
# 26577    4.80
# 26578    4.80
# 26579    4.80
# 26580    4.80
# 26581    4.80
# Name: review_scores_rating, Length: 26582, dtype: float64

# %%
Min = df['review_scores_rating'].min()
Max = df['review_scores_rating'].max()

intervalos = [Min - 1, 4.8, Max]  # Min - 1 para asegurar incluir valores mínimos
categorias = ["Menos de 4.8", "4.8 o más"]

df['review_scores_rating'] = pd.cut(df['review_scores_rating'], bins=intervalos, labels=categorias, right=True)
df['review_scores_rating']
# Out:
# 0        Menos de 4.8
# 1        Menos de 4.8
# 2           4.8 o más
# 3           4.8 o más
# 4           4.8 o más
#              ...
# 26577    Menos de 4.8
# 26578    Menos de 4.8
# 26579    Menos de 4.8
# 26580    Menos de 4.8
# 26581    Menos de 4.8
# Name: review_scores_rating, Length: 26582, dtype: category
# Categories (2, object): ['Menos de 4.8' < '4.8 o más']

# %%
Vars_Indep=df[['review_scores_cleanliness','review_scores_accuracy','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value']]
Var_Dep=df['review_scores_rating']
X= Vars_Indep
y= Var_Dep
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['Menos de 4.8', 'Menos de 4.8', 'Menos de 4.8', ...,
#        'Menos de 4.8', '4.8 o más', 'Menos de 4.8'], dtype=object)

# %%
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[3290  596]
#  [ 316 3773]]

# %%
precision17 = precision_score(y_test, y_pred, average="binary", pos_label="4.8 o más") 
print("Precisión del modelo: ")
print(precision17)
# Out:
# Precisión del modelo:
# 0.9123682750970604

# %%
precision18 = precision_score(y_test, y_pred, average="binary", pos_label="Menos de 4.8") 
print("Precisión del modelo: ")
print(precision18)
# Out:
# Precisión del modelo:
# 0.863584344243534

# %%
exactitud9 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud9)
# Out:
# Exactitud del modelo:
# 0.8856426332288401

# %%
sensibilidad17 = recall_score(y_test, y_pred, average="binary", pos_label="4.8 o más")
print("Sensibilidad del modelo: ")
print(sensibilidad17)
# Out:
# Sensibilidad del modelo:
# 0.8466289243437982

# %%
sensibilidad18 = recall_score(y_test, y_pred, average="binary", pos_label="Menos de 4.8")
print("Sensibilidad del modelo: ")
print(sensibilidad18)
# Out:
# Sensibilidad del modelo:
# 0.9227194913181707

# %% [markdown]
# **price vs accommodates, bathrooms, bedrooms & beds**

# %%
df = pd.read_csv('México por IQR2.csv')
df =df.drop(labels=["Unnamed: 0"], axis=1)
df
# Out:
#                         id           source  \
# 0                    35797      city scrape
# 1                    44616  previous scrape
# 2                    67703      city scrape
# 3                    70644      city scrape
# 4                   107078      city scrape
# ...                    ...              ...
# 26577  1252141718111439700      city scrape
# 26578  1252159821531694005      city scrape
# 26579  1252185591721328995      city scrape
# 26580  1252218347521498445      city scrape
# 26581  1252229157495978163      city scrape
#
#                                                    name  \
# 0                                           Villa Dante
# 1                                          Condesa Haus
# 2                     2 bedroom apt. deco bldg, Condesa
# 3      Beautiful light Studio Coyoacan- full equipped !
# 4                                    NEW  DESIGNER LOFT
# ...                                                 ...
# ...

# %%
df['price']
# Out:
# 0        1093.130000
# 1        1511.712311
# 2        2029.000000
# 3        1140.000000
# 4        1093.130000
#             ...
# 26577     488.000000
# 26578    1093.130000
# 26579    2700.000000
# 26580    2600.000000
# 26581    1353.000000
# Name: price, Length: 26582, dtype: float64

# %%
df['price']=df['price']/22
df['price']
# Out:
# 0         49.687727
# 1         68.714196
# 2         92.227273
# 3         51.818182
# 4         49.687727
#             ...
# 26577     22.181818
# 26578     49.687727
# 26579    122.727273
# 26580    118.181818
# 26581     61.500000
# Name: price, Length: 26582, dtype: float64

# %%
promedio_price = df['price'].mean()
print(promedio_price)
# Out:
# 49.687537082619286

# %%
Min = df['price'].min()
Max = df['price'].max()

intervalos = [Min - 1,50 , Max]  # Min - 1 para asegurar incluir valores mínimos
categorias = ["Menos de 50", "50 o más"]

df['price'] = pd.cut(df['price'], bins=intervalos, labels=categorias, right=True)
df['price']
# Out:
# 0        Menos de 50
# 1           50 o más
# 2           50 o más
# 3           50 o más
# 4        Menos de 50
#             ...
# 26577    Menos de 50
# 26578    Menos de 50
# 26579       50 o más
# 26580       50 o más
# 26581       50 o más
# Name: price, Length: 26582, dtype: category
# Categories (2, object): ['Menos de 50' < '50 o más']

# %%
Vars_Indep=df[['accommodates','bathrooms','bedrooms','beds']]
Var_Dep=df['price']
X= Vars_Indep
y= Var_Dep
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=None)
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['50 o más', '50 o más', 'Menos de 50', ..., 'Menos de 50',
#        '50 o más', '50 o más'], dtype=object)

# %%
matriz = confusion_matrix(y_test, y_pred)
print ('Matriz de Confusión: ')
print(matriz)
# Out:
# Matriz de Confusión:
# [[1431 1910]
#  [ 973 3661]]

# %%
precision19 = precision_score(y_test, y_pred, average="binary", pos_label="50 o más") 
print("Precisión del modelo: ")
print(precision19)
# Out:
# Precisión del modelo:
# 0.5952579034941764

# %%
precision20 = precision_score(y_test, y_pred, average="binary", pos_label="Menos de 50") 
print("Precisión del modelo: ")
print(precision20)
# Out:
# Precisión del modelo:
# 0.6571531143421289

# %%
exactitud10 = accuracy_score(y_test,y_pred)
print("Exactitud del modelo: ")
print(exactitud10)
# Out:
# Exactitud del modelo:
# 0.6384952978056426

# %%
sensibilidad19 = recall_score(y_test, y_pred, average="binary", pos_label="50 o más")
print("Sensibilidad del modelo: ")
print(sensibilidad19)
# Out:
# Sensibilidad del modelo:
# 0.4283148757856929

# %%
sensibilidad20 = recall_score(y_test, y_pred, average="binary", pos_label="Menos de 50")
print("Sensibilidad del modelo: ")
print(sensibilidad20)
# Out:
# Sensibilidad del modelo:
# 0.7900302114803626

# %%
print("Tabla de estadísticos de regresión logística")
print("1 hace referencia a valores true o categorías con valores mayores, 2 a valores false o categorías con valores menores.")
resultados = {
    'Métrica': ['Precisión T o >','Precisión F o <', 'Sensibilidad T o >','Sensibilidad F o >','Exactitud'],
    'instant_bookable': [precision1,precision2,sensibilidad1,sensibilidad2,exactitud1],
    'source': [precision3,precision4,sensibilidad3,sensibilidad4,exactitud2], #city scrape es true, previous scrape es false
    'host_is_superhost': [precision5,precision6,sensibilidad5,sensibilidad6,exactitud3],
    'has_availability': [precision7,precision8,sensibilidad7,sensibilidad8,exactitud4],
    'neighbourhood_group_cleansed': [precision9,precision10,sensibilidad9,sensibilidad10,exactitud5], #Cuauhtémoc es true y No Cuauhtém es false
    'room_type': [precision11,precision12,sensibilidad11,sensibilidad12,exactitud6], #Entire home/apt es true, #No Entire home es false
    'accommodates': [precision13,precision14,sensibilidad13,sensibilidad14,exactitud7], #Más de 3 es true, 3 o menos es false
    'reviews_per_month': [precision15,precision16,sensibilidad15,sensibilidad16,exactitud8], #Más de 1 es true, 1 o menos es false
    'review_scores_rating': [precision17,precision18,sensibilidad17,sensibilidad18,exactitud9], #4.8 o más es true, menos de 4.8 es false
    'price': [precision19,precision20,sensibilidad19,sensibilidad20,exactitud10] # Más de 50 es true, menos de 50 es false
}

# Convertirlo en DataFrame
df_resultados = pd.DataFrame(resultados)

# Mostrar la tabla
df_resultados
# Out:
# Tabla de estadísticos de regresión logística
# 1 hace referencia a valores true o categorías con valores mayores, 2 a valores false o categorías con valores menores.
#               Métrica  instant_bookable    source  host_is_superhost  \
# 0     Precisión T o >          0.548122  0.897589           0.366961
# 1     Precisión F o <          0.625298  0.386973           0.613711
# 2  Sensibilidad T o >          0.148916  0.977414           0.190820
# 3  Sensibilidad F o >          0.920438  0.113356           0.796142
# 4           Exactitud          0.617053  0.880878           0.564639
#
#    has_availability  neighbourhood_group_cleansed  room_type  accommodates  \
# 0           0.99837                      0.593409   0.893654      0.815201
# 1           0.00000                      0.669231   0.577518      0.892270
# 2           1.00000                      0.637180   0.684061      0.793328
# 3           0.00000                      0.627063   0.841405      0.904926
# ...
